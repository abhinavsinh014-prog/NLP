# %%
sentence = "John Cena is a professional wrestler and actor.About his career, he has won multiple championships and has appeared in various films and television shows."

# %%
print(sentence)
# Out:
# John Cena is a professional wrestler and actor.About his career, he has won multiple championships and has appeared in various films and television shows.
