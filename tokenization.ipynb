# %%
corpus = """I am Abhinav Thakur. And a Former world middleweight champion.."""

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (2026.7.19)
# Requirement already satisfied: tqdm in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (4.70.0)
# Requirement already satisfied: colorama in C:\Users\abhin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk) (0.4.6)

# %%
print(corpus)
# Out:
# I am Abhinav Thakur. And a Former world middleweight champion..

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
doc = sent_tokenize(corpus)

# %%
type(doc)
# Out:
# list

# %%
for sentence in doc:
    print(sentence)
# Out:
# I am Abhinav Thakur.
# And a Former world middleweight champion..

# %%
from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)

# %%
words
# Out:
# ['I',
#  'am',
#  'Abhinav',
#  'Thakur',
#  '.',
#  'And',
#  'a',
#  'Former',
#  'world',
#  'middleweight',
#  'champion',
#  '..']

# %%
for i in doc:
    print(word_tokenize(i))
# Out:
# ['I', 'am', 'Abhinav', 'Thakur', '.']
# ['And', 'a', 'Former', 'world', 'middleweight', 'champion', '..']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wops = word_tokenize(corpus)

# %%
wops
# Out:
# ['I',
#  'am',
#  'Abhinav',
#  'Thakur',
#  '.',
#  'And',
#  'a',
#  'Former',
#  'world',
#  'middleweight',
#  'champion',
#  '..']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
TreebankWordTokenizer().tokenize(corpus)
# Out:
# ['I',
#  'am',
#  'Abhinav',
#  'Thakur.',
#  'And',
#  'a',
#  'Former',
#  'world',
#  'middleweight',
#  'champion..']
