# %%
para = """I am an AI/ML-focused developer passionate about building practical intelligent applications and continuously expanding my knowledge in Artificial Intelligence.

My current foundation is built around Python, Streamlit, Machine Learning, and Deep Learning. I enjoy taking theoretical concepts and turning them into functional applications that solve practical problems.

I am currently gaining professional experience through an AI Internship at Smarted, where I am developing practical exposure to AI-focused development and real-world problem solving.

My next major learning goals are Large Language Models (LLMs), Retrieval-Augmented Generation (RAG), and Agentic AI."""

# %%
print(para)
# Out:
# I am an AI/ML-focused developer passionate about building practical intelligent applications and continuously expanding my knowledge in Artificial Intelligence.
#
# My current foundation is built around Python, Streamlit, Machine Learning, and Deep Learning. I enjoy taking theoretical concepts and turning them into functional applications that solve practical problems.
#
# I am currently gaining professional experience through an AI Internship at Smarted, where I am developing practical exposure to AI-focused development and real-world problem solving.
#
# My next major learning goals are Large Language Models (LLMs), Retrieval-Augmented Generation (RAG), and Agentic AI.

# %%
from nltk.corpus import stopwords

# %%
from nltk.stem import PorterStemmer
stemmer= PorterStemmer()

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwards = set(stopwords.words('english'))

# %%
stopwards
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sentence = nltk.sent_tokenize(para)

# %%
type(sentence)
# Out:
# list

# %%
for i in range(len(sentence)):
  words=nltk.word_tokenize(sentence[i])
  words=[stemmer.stem(word) for word in words if word not in set(stopwards)]
  sentence[i] = ' '.join(words)

# %%
sentence
# Out:
# ['i ai/ml-focus develop passion build practic intellig applic continu expand knowledg artifici intellig .',
#  'my current foundat built around python , streamlit , machin learn , deep learn .',
#  'i enjoy take theoret concept turn function applic solv practic problem .',
#  'i current gain profession experi ai internship smart , i develop practic exposur ai-focus develop real-world problem solv .',
#  'my next major learn goal larg languag model ( llm ) , retrieval-aug gener ( rag ) , agent ai .']

# %%
from nltk.stem import SnowballStemmer

# %%
snowball = SnowballStemmer('english')

# %%
for i in range(len(sentence)):
  words=nltk.word_tokenize(sentence[i])
  words=[snowball.stem(word) for word in words if word not in set(stopwards)]
  sentence[i] = ' '.join(words)

# %%
sentence
# Out:
# ['ai/ml-focus develop passion build practic intellig applic continu expand knowledg artifici intellig .',
#  'current foundat built around python , streamlit , machin learn , deep learn .',
#  'enjoy take theoret concept turn function applic solv practic problem .',
#  'current gain profess experi ai internship smart , develop practic exposur ai-focus develop real-world problem solv .',
#  'next major learn goal larg languag model ( llm ) , retrieval-aug gener ( rag ) , agent ai .']

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#lemmitasation
from nltk.stem import WordNetLemmatizer
lemmi = WordNetLemmatizer()

for i in range(len(sentence)):
  words=nltk.word_tokenize(sentence[i])
  words=[lemmi.lemmatize(word) for word in words if word not in set(stopwards)]
  sentence[i] = ' '.join(words)

# %%
sentence
# Out:
# ['ai/ml-focus develop passion build practic intellig applic continu expand knowledg artifici intellig .',
#  'current foundat built around python , streamlit , machin learn , deep learn .',
#  'enjoy take theoret concept turn function applic solv practic problem .',
#  'current gain profess experi ai internship smart , develop practic exposur ai-focus develop real-world problem solv .',
#  'next major learn goal larg languag model ( llm ) , retrieval-aug gener ( rag ) , agent ai .']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
# we will find pos tag

for i in range(len(sentence)):
  words=nltk.word_tokenize(sentence[i])
  words=[word for word in words if word not in set(stopwards)]
  pos_tag= nltk.pos_tag(words)
  print(pos_tag)
# Out:
# [('ai/ml-focus', 'JJ'), ('develop', 'NN'), ('passion', 'NN'), ('build', 'VB'), ('practic', 'JJ'), ('intellig', 'NNS'), ('applic', 'JJ'), ('continu', 'NN'), ('expand', 'NN'), ('knowledg', 'NN'), ('artifici', 'NN'), ('intellig', 'NN'), ('.', '.')]
# [('current', 'JJ'), ('foundat', 'NN'), ('built', 'VBN'), ('around', 'IN'), ('python', 'NN'), (',', ','), ('streamlit', 'NN'), (',', ','), ('machin', 'NN'), ('learn', 'NN'), (',', ','), ('deep', 'JJ'), ('learn', 'NN'), ('.', '.')]
# [('enjoy', 'NNS'), ('take', 'VBP'), ('theoret', 'JJ'), ('concept', 'NN'), ('turn', 'NN'), ('function', 'NN'), ('applic', 'JJ'), ('solv', 'NN'), ('practic', 'JJ'), ('problem', 'NN'), ('.', '.')]
# [('current', 'JJ'), ('gain', 'NN'), ('profess', 'NN'), ('experi', 'NN'), ('ai', 'VBP'), ('internship', 'JJ'), ('smart', 'NN'), (',', ','), ('develop', 'VB'), ('practic', 'JJ'), ('exposur', 'NN'), ('ai-focus', 'JJ'), ('develop', 'NN'), ('real-world', 'NN'), ('problem', 'NN'), ('solv', 'NN'), ('.', '.')]
# ...

# %%
tokenized_sentence = nltk.word_tokenize("Your head is full of hair")
nltk.pos_tag_sents([tokenized_sentence])
# Out:
# [[('Your', 'PRP$'),
#   ('head', 'NN'),
#   ('is', 'VBZ'),
#   ('full', 'JJ'),
#   ('of', 'IN'),
#   ('hair', 'NN')]]
