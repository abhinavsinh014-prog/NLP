# %%
import nltk

nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize

resume = {
    "name": "John Doe",
    "role": "Software Engineer",
    "skills": ["Python", "JavaScript", "React", "Django"],
    "experience": ["2 years"]
}

text = f"""
Name: {resume['name']}
Role: {resume['role']}
Skills: {', '.join(resume['skills'])}
Experience: {resume['experience'][0]}
"""

doc = sent_tokenize(text)

print(doc)
# Out:
# ['\nName: John Doe\nRole: Software Engineer\nSkills: Python, JavaScript, React, Django\nExperience: 2 years']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
for sent in doc:
  print(sent)
# Out:
# Name: John Doe
# Role: Software Engineer
# Skills: Python, JavaScript, React, Django
# Experience: 2 years

# %%
word = nltk.word_tokenize(text)

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stemmer= PorterStemmer()
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmi = WordNetLemmatizer()

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

word = nltk.word_tokenize(text)

for i in range(len(word)):
  tokens_to_process = nltk.word_tokenize(word[i])

  processed_tokens = []
  for token in tokens_to_process:
    lower_token = token.lower()
    if lower_token not in stop_words:
      processed_tokens.append(lemmi.lemmatize(lower_token))

  word[i] = ' '.join(processed_tokens)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
word
# Out:
# ['name',
#  ':',
#  'john',
#  'doe',
#  'role',
#  ':',
#  'software',
#  'engineer',
#  'skill',
#  ':',
#  'python',
#  ',',
#  'javascript',
#  ',',
#  'react',
#  ',',
#  'django',
#  'experience',
#  ':',
#  '2',
#  'year']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


def calculate_match(resume_text, job_description):

    vectorizer = TfidfVectorizer()

    vectors = vectorizer.fit_transform(
        [resume_text, job_description]
    )

    similarity = cosine_similarity(
        vectors[0:1],
        vectors[1:2]
    )

    match_score = similarity[0][0] * 100

    return round(match_score, 2)

# %%
score = calculate_match(text, ' '.join(word))

# %%
print(score)
# Out:
# 73.58
